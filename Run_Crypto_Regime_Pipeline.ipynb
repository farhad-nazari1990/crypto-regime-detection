# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/project/crypto_regime_detection/version2/"
# Out:
# config.yaml  marketing	requirements.txt  Run_Crypto_Regime_Pipeline.ipynb
# data	     notebooks	results		  src
# file-v2.py   README.me	run_all.py

# %%
# %cd /content/drive/MyDrive/project/crypto_regime_detection/version2/
# Out:
# /content/drive/MyDrive/project/crypto_regime_detection/version2

# %%
# !ls -la
# Out:
# total 185
# -rw------- 1 root root   1013 Dec  6 10:35 config.yaml
# drwx------ 5 root root   4096 Dec  6 10:54 data
# -rw------- 1 root root 128962 Dec  6 09:58 file-v2.py
# -rw------- 1 root root    374 Dec  6 10:35 .gitignore
# drwx------ 2 root root   4096 Dec  6 10:54 marketing
# drwx------ 2 root root   4096 Dec  6 10:54 notebooks
# -rw------- 1 root root   6632 Dec  5 12:44 README.me
# -rw------- 1 root root    179 Dec  6 10:34 requirements.txt
# drwx------ 5 root root   4096 Dec  6 10:54 results
# -rw------- 1 root root   4990 Dec  6 10:36 run_all.py
# -rw------- 1 root root  25431 Dec  6 17:00 Run_Crypto_Regime_Pipeline.ipynb
# drwx------ 7 root root   4096 Dec  6 10:54 src

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: yfinance>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.2.66)
# Requirement already satisfied: hmmlearn>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.3.3)
# Requirement already satisfied: ruptures>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (1.1.10)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.5.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.2.0->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r requirements.txt (line 6)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.0->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.2.0->-r requirements.txt (line 6)) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.0->-r requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.0->-r requirements.txt (line 6)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.2.0->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.0->-r requirements.txt (line 6)) (2.23)

# %%
# !apt-get install tree -y
# !tree -L 3 -I '__pycache__|*.pyc'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (68.7 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# .
# ├── config.yaml
# ├── data
# │   ├── prcessed
# │   ├── processed
# │   │   ├── btc_clean.csv
# │   │   ├── features.csv
# │   │   └── features_scaled.csv
# │   └── raw
# │       └── btc_raw.csv
# ├── file-v2.py
# ├── marketing
# │   └── linkedin_post.md
# ├── notebooks
# │   ├── 01_EDA.ipynb
# │   ├── 02_Feature_Analysis.ipynb
# │   ├── 03_HMM_Modeling.ipynb
# │   ├── 04_GMM_Comparison.ipynb
# │   ├── 05_ChangePointDetection.ipynb
# │   └── 06_Presentation.ipynb
# ├── README.me
# ├── requirements.txt
# ├── results
# │   ├── models
# │   │   ├── gmm_model.pkl
# │   │   ├── hmm_model.pkl
# │   │   └── scaler.pkl
# │   ├── plots
# │   │   └── hmm_vs_gmm_confusion.png
# │   └── tables
# │       ├── cpd_points.csv
# │       ├── gmm_labels.csv
# │       ├── hmm_labels.csv
# │       ├── hmm_transition_matrix.csv
# │       ├── model_comparison.csv
# │       └── performance_per_regime.csv
# ├── run_all.py
# ├── Run_Crypto_Regime_Pipeline.ipynb
# └── src
#     ├── data
#     │   ├── clean_data.py
#     │   ├── load_data.py
#     │   └── save_processed.py
#     ├── evaluation
#     │   ├── compare_models.py
#     │   ├── describe_states.py
#     │   ├── metrics.py
#     │   └── performance_by_regime.py
#     ├── features
#     │   ├── build_features.py
#     │   └── feature_config.py
#     ├── models
#     │   ├── change_point_detection.py
#     │   ├── gmm_baseline.py
#     │   ├── hmm_model.py
#     │   └── hmm_utils.py
#     └── viz
#         ├── plot_cpd.py
#         ├── plot_feature_distributions.py
#         └── plot_regimes.py
#
# 16 directories, 43 files

# %%
# Cell جدید - Code
import os

# ساخت فولدرهای مورد نیاز
folders = [
    'data/raw',
    'data/processed',
    'results/models',
    'results/plots',
    'results/tables'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✓ Created/Verified: {folder}")
# Out:
# ✓ Created/Verified: data/raw
# ✓ Created/Verified: data/processed
# ✓ Created/Verified: results/models
# ✓ Created/Verified: results/plots
# ✓ Created/Verified: results/tables

# %%
# Cell جدید - Code
# بررسی اینکه تمام فایل‌های پایتون در src موجود هستند
import os

required_files = [
    'src/data/load_data.py',
    'src/data/clean_data.py',
    'src/data/save_processed.py',
    'src/features/feature_config.py',
    'src/features/build_features.py',
    'src/models/hmm_model.py',
    'src/models/hmm_utils.py',
    'src/models/gmm_baseline.py',
    'src/models/change_point_detection.py',
    'src/evaluation/performance_by_regime.py',
    'src/evaluation/describe_states.py',
    'src/evaluation/metrics.py',
    'src/evaluation/compare_models.py',
    'src/viz/plot_regimes.py',
    'src/viz/plot_cpd.py',
    'src/viz/plot_feature_distributions.py'
]

print("Checking required files...")
missing_files = []
for file in required_files:
    if os.path.exists(file):
        print(f"✓ {file}")
    else:
        print(f"✗ MISSING: {file}")
        missing_files.append(file)

if missing_files:
    print(f"\n⚠️ {len(missing_files)} files are missing!")
else:
    print("\n✅ All required files exist!")
# Out:
# Checking required files...
# ✓ src/data/load_data.py
# ✓ src/data/clean_data.py
# ✓ src/data/save_processed.py
# ✓ src/features/feature_config.py
# ✓ src/features/build_features.py
# ✓ src/models/hmm_model.py
# ✓ src/models/hmm_utils.py
# ✓ src/models/gmm_baseline.py
# ✓ src/models/change_point_detection.py
# ✓ src/evaluation/performance_by_regime.py
# ✓ src/evaluation/describe_states.py
# ✓ src/evaluation/metrics.py
# ✓ src/evaluation/compare_models.py
# ✓ src/viz/plot_regimes.py
# ✓ src/viz/plot_cpd.py
# ✓ src/viz/plot_feature_distributions.py
#
# ✅ All required files exist!

# %%
# Cell جدید - Code
# اجرای کامل pipeline
# !python run_all.py --config config.yaml
# Out:
# ============================================================
# CRYPTO REGIME DETECTION PIPELINE
# ============================================================
# \n[1/9] Loading raw BTC data...
# Downloading BTC-USD data (attempt 1/3)...
# ✓ Downloaded 4099 rows from 2014-09-17 00:00:00+00:00 to 2025-12-06 00:00:00+00:00
# ✓ Saved to data/raw/btc_raw.csv
# ✓ Loaded 4099 rows
# \n[2/9] Cleaning data...
# Cleaning data...
# /content/drive/MyDrive/project/crypto_regime_detection/version2/src/data/clean_data.py:44: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')
#   Created return and volatility features
#   Removed 5 rows with NaN from rolling calculations
# ✓ Cleaned data: 4094 rows, 10 columns
#   Date range: 2014-09-22 00:00:00+00:00 to 2025-12-06 00:00:00+00:00
# ✓ Cleaned data saved to data/processed/btc_clean.csv
# \n[3/9] Building and scaling features...
# Building features...
#   ✓ Volatility features: [5, 20]
#   ✓ Momentum features: [5, 10, 21]
#   ✓ Z-score features (window=20)
#   ✓ Volume features (window=20)
#   ✓ Price change features
#   ✓ RSI (window=14)
#   ✓ Bollinger Bands
#   Removed 21 rows with NaN
# ✓ Built 13 new features
# ✓ Saved unscaled features to data/processed/features.csv
# Scaling features using standard scaler...
# ✓ Scaled 22 features
# ✓ Saved scaler to results/models/scaler.pkl
# ✓ Saved scaled features to data/processed/features_scaled.csv
# ✓ Created 23 features
# \n[4/9] Training HMM model...
# Training HMM with 4 states...
#   Using 22 features
#   Training samples: 4073
# ✓ HMM training complete
#   Log-likelihood: 152871.25
#   Converged: True
# ✓ Saved model to results/models/hmm_model.pkl
# ✓ Saved labels to results/tables/hmm_labels.csv
# ✓ Saved transition matrix to results/tables/hmm_transition_matrix.csv
# \n  State distribution:
#     State 0: 575 days (14.1%)
#     State 1: 696 days (17.1%)
#     State 2: 1563 days (38.4%)
#     State 3: 1239 days (30.4%)
# ✓ HMM trained with 4 states
# \n[5/9] Training GMM baseline...
# Training GMM with 4 components...
#   Using 22 features
#   Training samples: 4073
# ✓ GMM training complete
#   BIC: -245694.25
#   AIC: -252656.53
#   Converged: True
# ✓ Saved model to results/models/gmm_model.pkl
# ✓ Saved labels to results/tables/gmm_labels.csv
# \n  Cluster distribution:
#     Cluster 0: 1035 days (25.4%)
#     Cluster 1: 609 days (15.0%)
#     Cluster 2: 806 days (19.8%)
#     Cluster 3: 1623 days (39.8%)
# ✓ GMM trained with 4 components
# \n[6/9] Detecting change points...
# Detecting change points using Ruptures (rbf model)...
#   Signal shape: (4073, 22)
#   Using penalty: 24.94
# ✓ Detected 6 change points
# ✓ Saved change points to results/tables/cpd_points.csv
# \n  Change points detected at indices:
#     1. Index 930 (2017-04-30 00:00:00+00:00)
#     2. Index 1295 (2018-04-30 00:00:00+00:00)
#     3. Index 2265 (2020-12-25 00:00:00+00:00)
#     4. Index 2820 (2022-07-03 00:00:00+00:00)
#     5. Index 3405 (2024-02-08 00:00:00+00:00)
#     6. Index 3690 (2024-11-19 00:00:00+00:00)
# ✓ Detected 6 change points
# \n[7/9] Evaluating regime performance...
# Evaluating performance by regime...
#   ⚠️ Length mismatch detected:
#      DataFrame length: 4094
#      States length: 4073
#   ✓ Adjusted DataFrame to 4073 rows to match states
#   Analyzing State 0...
#   Analyzing State 1...
#   Analyzing State 2...
#   Analyzing State 3...
# ✓ Saved performance metrics to results/tables/performance_per_regime.csv
#
#   Performance Summary:
#  state  n_days  mean_daily_return  volatility  sharpe_ratio
#      0     575          -0.023707    0.060709     -7.460660
#      1     696           0.025330    0.043963     11.007318
#      2    1563           0.003037    0.017814      3.256751
#      3    1239          -0.000586    0.016333     -0.684888
# ✓ Performance metrics calculated
# \n[8/9] Comparing models...
# Comparing HMM and GMM models...
#   ⚠️ Adjusting DataFrame length:
#      DataFrame: 4094 -> 4073
#   Adjusted Rand Index: 0.5640
#   Normalized Mutual Info: 0.5143
# ✓ Saved confusion matrix to results/plots/hmm_vs_gmm_confusion.png
#   HMM transitions: 762
#   GMM transitions: 1008
#   HMM avg duration: 5.3 days
#   GMM avg duration: 4.0 days
# ✓ Saved comparison to results/tables/model_comparison.csv
# ✓ Saved timeline comparison to results/plots/hmm_vs_gmm_timeline.png
# ✓ Model comparison complete
# \n[9/9] Generating visualizations...
# Generating regime visualization...
#   ⚠️ Length mismatch detected:
#      DataFrame length: 4094
#      States length: 4073
#   ✓ Adjusted DataFrame to 4073 rows
# ✓ Saved regime plot to results/plots/regime_detection_plot.png
# ✓ Saved scatter plot to results/plots/regime_scatter_plot.png
# Generating change point detection visualization...
# ✓ Saved CPD plot to results/plots/change_point_detection.png
# ✓ Saved CPD segments plot to results/plots/cpd_segments.png
# Generating feature distribution plots...
# ✓ Saved feature distributions to results/plots/feature_distributions.png
# ✓ Saved box plots to results/plots/feature_boxplots.png
# /content/drive/MyDrive/project/crypto_regime_detection/version2/src/viz/plot_feature_distributions.py:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='state', y=feature, ax=axes[idx],
# /content/drive/MyDrive/project/crypto_regime_detection/version2/src/viz/plot_feature_distributions.py:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='state', y=feature, ax=axes[idx],
# /content/drive/MyDrive/project/crypto_regime_detection/version2/src/viz/plot_feature_distributions.py:140: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_plot, x='state', y=feature, ax=axes[idx],
# ✓ Saved violin plots to results/plots/feature_violins.png
# ✓ Plots saved to results/plots/
# \n============================================================
# ✓ PIPELINE COMPLETE!
# ============================================================
# \nResults saved to: results/
# \nOutputs:
#   - Models: results/models/
#   - Tables: results/tables/
#   - Plots: results/plots/
